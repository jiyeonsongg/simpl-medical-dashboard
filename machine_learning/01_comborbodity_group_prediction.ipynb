# %%
import pandas as pd

# %%
subgroup_1 = pd.read_csv('subgroup_1 (1).csv')

# %%
subgroup_2 = pd.read_csv('subgroup_2 (1).csv')

# %%
subgroup_3 = pd.read_csv('subgroup_3 (1).csv')

# %%
subgroup_4 = pd.read_csv('subgroup_4 (1).csv')

# %%
subgroup_5 = pd.read_csv('subgroup_5.csv')

# %%
subgroup_6 = pd.read_csv('subgroup_6 (1).csv')

# %%
subgroup_7 = pd.read_csv('subgroup_7 (1).csv')

# %%
df = pd.concat([subgroup_1, subgroup_2, subgroup_3, subgroup_4, subgroup_5, subgroup_6, subgroup_7], ignore_index =True)

# %%
df.to_csv('all_subgroups.csv')

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#use train but use cross validation to pick best parameters

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=  13.7s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   2.7s
# ...

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 100,
#  'max_features': 2,
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 1000}

# %%
rf = RandomForestClassifier(bootstrap = True,
 max_depth= 100,
 max_features= 2,
 min_samples_leaf= 3,
 min_samples_split= 8,
 n_estimators= 1000)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, max_features=2, min_samples_leaf=3,
#                        min_samples_split=8, n_estimators=1000)

# %%
sum(rf.predict(X_test) == y_test)/len(y_test)
# Out:
# 0.9254385964912281
